# %% [markdown]
# IMPORTING THE DATA

# %%
import pandas as pd
df=pd.read_csv("census_income.csv")
print (df)
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.head(10)
# Out:
#    Age          Workclass  Fnlwgt      Education  Education_num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            Marital_status          Occupation    Relationship    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %% [markdown]
# FEATURE ENGINEERING

# %%
def label_fix(label):
    if label==' <=50K':
        return 0
    else:
        return 1

# %%
df['Income'] = df['Income'].apply(label_fix)

# %%
df['Workclass']=df['Workclass'].str.replace('?','')

# %%
df['Workclass'].fillna(df['Workclass'].value_counts().index[0],inplace=True)

# %%
df['Workclass'].isnull().sum()
# Out:
# 0

# %%
df['Workclass1']=df['Workclass'].str.split('-').str[0]
df['Workclass2']=df['Workclass'].str.split('-').str[1]
df['Workclass3']=df['Workclass'].str.split('-').str[2]
df['Workclass4']=df['Workclass'].str.split('-').str[3]

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income  \
# ...

# %%
df=df.drop(['Workclass'],axis=1)

# %%
df['Education1']=df['Education'].str.split('-').str[0]
df['Education2']=df['Education'].str.split('-').str[1]

# %%
df=df.drop(['Education'],axis=1)

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num       Marital_status          Occupation  \
# 0   50   83311             13   Married-civ-spouse     Exec-managerial
# 1   38  215646              9             Divorced   Handlers-cleaners
# 2   53  234721              7   Married-civ-spouse   Handlers-cleaners
# 3   28  338409             13   Married-civ-spouse      Prof-specialty
# 4   37  284582             14   Married-civ-spouse     Exec-managerial
#
#      Relationship    Race      Sex  Capital_gain  Capital_loss  \
# 0         Husband   White     Male             0             0
# 1   Not-in-family   White     Male             0             0
# 2         Husband   Black     Male             0             0
# 3            Wife   Black   Female             0             0
# 4            Wife   White   Female             0             0
#
#    Hours_per_week  Native_country  Income Workclass1 Workclass2 Workclass3  \
# 0              13   United-States       1       Self        emp        not
# ...

# %%
df['Education1'].value_counts()
# Out:
#  HS           10501
#  Some          7291
#  Bachelors     5354
#  Assoc         2449
#  Masters       1723
#  11th          1175
#  10th           933
#  7th            646
#  Prof           576
#  9th            514
#  12th           433
#  Doctorate      413
#  5th            333
#  1st            168
#  Preschool       51
# Name: Education1, dtype: int64

# %%
df['Education3']=df['Education1'].str.split('th').str[0]

# %%
df['Occupation']=df['Occupation'].str.replace('?','')

# %%
df['Occupation'].fillna(df['Occupation'].value_counts().index[0],inplace=True)

# %%
df['Occupation'].isnull().sum()
# Out:
# 0

# %%
df['Occupation1']=df['Occupation'].str.split('-').str[0]
df['Occupation2']=df['Occupation'].str.split('-').str[1]

df['Occupation3']=df['Occupation'].str.split('-').str[2]

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num       Marital_status          Occupation  \
# 0   50   83311             13   Married-civ-spouse     Exec-managerial
# 1   38  215646              9             Divorced   Handlers-cleaners
# 2   53  234721              7   Married-civ-spouse   Handlers-cleaners
# 3   28  338409             13   Married-civ-spouse      Prof-specialty
# 4   37  284582             14   Married-civ-spouse     Exec-managerial
#
#      Relationship    Race      Sex  Capital_gain  Capital_loss  ...  \
# 0         Husband   White     Male             0             0  ...
# 1   Not-in-family   White     Male             0             0  ...
# 2         Husband   Black     Male             0             0  ...
# 3            Wife   Black   Female             0             0  ...
# 4            Wife   White   Female             0             0  ...
#
#    Workclass1 Workclass2  Workclass3 Workclass4  Education1 Education2  \
# ...

# %%
df=df.drop(['Occupation'],axis=1)
df=df.drop(['Marital_status'],axis=1)
df=df.drop(['Occupation3'],axis=1)

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Relationship    Race      Sex  Capital_gain  \
# 0   50   83311             13         Husband   White     Male             0
# 1   38  215646              9   Not-in-family   White     Male             0
# 2   53  234721              7         Husband   Black     Male             0
# 3   28  338409             13            Wife   Black   Female             0
# 4   37  284582             14            Wife   White   Female             0
#
#    Capital_loss  Hours_per_week  Native_country  Income Workclass1 Workclass2  \
# 0             0              13   United-States       1       Self        emp
# 1             0              40   United-States       1    Private        NaN
# 2             0              40   United-States       1    Private        NaN
# 3             0              40            Cuba       1    Private        NaN
# 4             0              40   United-States       1    Private        NaN
#
# ...

# %%
df['Relationship1']=df['Relationship'].str.split('-').str[0]
df['Relationship2']=df['Relationship'].str.split('-').str[1]
df['Relationship3']=df['Relationship'].str.split('-').str[2]

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Relationship    Race      Sex  Capital_gain  \
# 0   50   83311             13         Husband   White     Male             0
# 1   38  215646              9   Not-in-family   White     Male             0
# 2   53  234721              7         Husband   Black     Male             0
# 3   28  338409             13            Wife   Black   Female             0
# 4   37  284582             14            Wife   White   Female             0
#
#    Capital_loss  Hours_per_week  Native_country  ...  Workclass3 Workclass4  \
# 0             0              13   United-States  ...         not        inc
# 1             0              40   United-States  ...         NaN        NaN
# 2             0              40   United-States  ...         NaN        NaN
# 3             0              40            Cuba  ...         NaN        NaN
# 4             0              40   United-States  ...         NaN        NaN
#
# ...

# %%
df=df.drop(['Relationship'],axis=1)
df=df.drop(['Relationship2'],axis=1)
df=df.drop(['Relationship3'],axis=1)

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Race      Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13   White     Male             0             0
# 1   38  215646              9   White     Male             0             0
# 2   53  234721              7   Black     Male             0             0
# 3   28  338409             13   Black   Female             0             0
# 4   37  284582             14   White   Female             0             0
#
#    Hours_per_week  Native_country  Income Workclass1 Workclass2 Workclass3  \
# 0              13   United-States       1       Self        emp        not
# 1              40   United-States       1    Private        NaN        NaN
# 2              40   United-States       1    Private        NaN        NaN
# 3              40            Cuba       1    Private        NaN        NaN
# 4              40   United-States       1    Private        NaN        NaN
#
# ...

# %%
df['Native_country']=df['Native_country'].str.replace('?','')

# %%
df['Native_country'].fillna(df['Native_country'].value_counts().index[0],inplace=True)

# %%
df['Native_country'].isnull().sum()
# Out:
# 0

# %%
df['Native_country1']=df['Native_country'].str.split('-').str[0]
df['Native_country2']=df['Native_country'].str.split('-').str[1]

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Race      Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13   White     Male             0             0
# 1   38  215646              9   White     Male             0             0
# 2   53  234721              7   Black     Male             0             0
# 3   28  338409             13   Black   Female             0             0
# 4   37  284582             14   White   Female             0             0
#
#    Hours_per_week  Native_country  Income  ... Workclass3 Workclass4  \
# 0              13   United-States       1  ...        not        inc
# 1              40   United-States       1  ...        NaN        NaN
# 2              40   United-States       1  ...        NaN        NaN
# 3              40            Cuba       1  ...        NaN        NaN
# 4              40   United-States       1  ...        NaN        NaN
#
#    Education1 Education2  Education3 Occupation1 Occupation2 Relationship1  \
# ...

# %%
df=df.drop(['Native_country2'],axis=1)
df=df.drop(['Native_country'],axis=1)

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Race      Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13   White     Male             0             0
# 1   38  215646              9   White     Male             0             0
# 2   53  234721              7   Black     Male             0             0
# 3   28  338409             13   Black   Female             0             0
# 4   37  284582             14   White   Female             0             0
#
#    Hours_per_week  Income Workclass1 Workclass2 Workclass3 Workclass4  \
# 0              13       1       Self        emp        not        inc
# 1              40       1    Private        NaN        NaN        NaN
# 2              40       1    Private        NaN        NaN        NaN
# 3              40       1    Private        NaN        NaN        NaN
# 4              40       1    Private        NaN        NaN        NaN
#
#    Education1 Education2  Education3 Occupation1 Occupation2 Relationship1  \
# ...

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Race      Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13   White     Male             0             0
# 1   38  215646              9   White     Male             0             0
# 2   53  234721              7   Black     Male             0             0
# 3   28  338409             13   Black   Female             0             0
# 4   37  284582             14   White   Female             0             0
#
#    Hours_per_week  Income Workclass1 Workclass2  Education1  Education3  \
# 0              13       1       Self        emp   Bachelors   Bachelors
# 1              40       1    Private        NaN          HS          HS
# 2              40       1    Private        NaN        11th          11
# 3              40       1    Private        NaN   Bachelors   Bachelors
# 4              40       1    Private        NaN     Masters     Masters
#
#   Occupation1 Occupation2 Relationship1 Native_country1
# ...

# %%
df=df.drop(['Workclass2'],axis=1)

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Race      Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13   White     Male             0             0
# 1   38  215646              9   White     Male             0             0
# 2   53  234721              7   Black     Male             0             0
# 3   28  338409             13   Black   Female             0             0
# 4   37  284582             14   White   Female             0             0
#
#    Hours_per_week  Income Workclass1  Education1  Education3 Occupation1  \
# 0              13       1       Self   Bachelors   Bachelors        Exec
# 1              40       1    Private          HS          HS    Handlers
# 2              40       1    Private        11th          11    Handlers
# 3              40       1    Private   Bachelors   Bachelors        Prof
# 4              40       1    Private     Masters     Masters        Exec
#
#   Occupation2 Relationship1 Native_country1
# ...

# %%
df["Education3"].value_counts()
# Out:
#  HS           10501
#  Some          7291
#  Bachelors     5354
#  Assoc         2449
#  Masters       1723
#  11            1175
#  10             933
#  7              646
#  Prof           576
#  9              514
#  12             433
#  Doctorate      413
#  5              333
#  1st            168
#  Preschool       51
# Name: Education3, dtype: int64

# %%
df['Education4']=df['Education3'].str.split('st').str[0]
df['Education5']=df['Education3'].str.split('st').str[1]

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Race      Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13   White     Male             0             0
# 1   38  215646              9   White     Male             0             0
# 2   53  234721              7   Black     Male             0             0
# 3   28  338409             13   Black   Female             0             0
# 4   37  284582             14   White   Female             0             0
#
#    Hours_per_week  Income Workclass1  Education1  Education3 Occupation1  \
# 0              13       1       Self   Bachelors   Bachelors        Exec
# 1              40       1    Private          HS          HS    Handlers
# 2              40       1    Private        11th          11    Handlers
# 3              40       1    Private   Bachelors   Bachelors        Prof
# 4              40       1    Private     Masters     Masters        Exec
#
#   Occupation2 Relationship1 Native_country1  Education4 Education5
# ...

# %%
df=df.drop(['Education1'],axis=1)
df=df.drop(['Education3'],axis=1)
df=df.drop(['Education5'],axis=1)

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num    Race      Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13   White     Male             0             0
# 1   38  215646              9   White     Male             0             0
# 2   53  234721              7   Black     Male             0             0
# 3   28  338409             13   Black   Female             0             0
# 4   37  284582             14   White   Female             0             0
#
#    Hours_per_week  Income Workclass1 Occupation1 Occupation2 Relationship1  \
# 0              13       1       Self        Exec  managerial       Husband
# 1              40       1    Private    Handlers    cleaners           Not
# 2              40       1    Private    Handlers    cleaners       Husband
# 3              40       1    Private        Prof   specialty          Wife
# 4              40       1    Private        Exec  managerial          Wife
#
#   Native_country1  Education4
# 0          United   Bachelors
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Education4"]=LE.fit_transform(df["Education4"])

# %%
df["Education4"].value_counts()
# Out:
# 10    10501
# 14     7291
# 8      5354
# 7      2449
# 11     1723
# 2      1175
# 1       933
# 5       646
# 13      576
# 6       514
# 3       433
# 9       413
# 4       333
# 0       168
# 12       51
# Name: Education4, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Race"]=LE.fit_transform(df["Race"])
df["Sex"]=LE.fit_transform(df["Sex"])
df["Workclass1"]=LE.fit_transform(df["Workclass1"])
df["Occupation1"]=LE.fit_transform(df["Occupation1"])
df["Occupation2"]=LE.fit_transform(df["Occupation2"])

df["Relationship1"]=LE.fit_transform(df["Relationship1"])
df["Native_country1"]=LE.fit_transform(df["Native_country1"])

# %%
df.head()
# Out:
#    Age  Fnlwgt  Education_num  Race  Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13     4    1             0             0
# 1   38  215646              9     4    1             0             0
# 2   53  234721              7     2    1             0             0
# 3   28  338409             13     2    0             0             0
# 4   37  284582             14     4    0             0             0
#
#    Hours_per_week  Income  Workclass1  Occupation1  Occupation2  \
# 0              13       1           5            4            5
# 1              40       1           4            6            1
# 2              40       1           4            6            1
# 3              40       1           4           10           11
# 4              40       1           4            4            5
#
#    Relationship1  Native_country1  Education4
# 0              0               39           8
# 1              1               39          10
# ...

# %%
df.dtypes
# Out:
# Age                int64
# Fnlwgt             int64
# Education_num      int64
# Race               int32
# Sex                int32
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Income             int64
# Workclass1         int32
# Occupation1        int32
# Occupation2        int32
# Relationship1      int32
# Native_country1    int32
# Education4         int32
# dtype: object

# %% [markdown]
# SPLITTING INTO X AND Y

# %%
x=df.drop("Income",axis=1)
y=df["Income"]
x.head()
# Out:
#    Age  Fnlwgt  Education_num  Race  Sex  Capital_gain  Capital_loss  \
# 0   50   83311             13     4    1             0             0
# 1   38  215646              9     4    1             0             0
# 2   53  234721              7     2    1             0             0
# 3   28  338409             13     2    0             0             0
# 4   37  284582             14     4    0             0             0
#
#    Hours_per_week  Workclass1  Occupation1  Occupation2  Relationship1  \
# 0              13           5            4            5              0
# 1              40           4            6            1              1
# 2              40           4            6            1              0
# 3              40           4           10           11              5
# 4              40           4            4            5              5
#
#    Native_country1  Education4
# 0               39           8
# 1               39          10
# ...

# %% [markdown]
# SCALING

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
scaled = mms.fit_transform(df)
print(scaled)
# Out:
# [[0.45205479 0.0482376  0.8        ... 0.         0.95121951 0.57142857]
#  [0.28767123 0.13811345 0.53333333 ... 0.2        0.95121951 0.71428571]
#  [0.49315068 0.15106831 0.4        ... 0.         0.95121951 0.14285714]
#  ...
#  [0.56164384 0.09482688 0.53333333 ... 0.8        0.95121951 0.71428571]
#  [0.06849315 0.12849934 0.53333333 ... 0.6        0.95121951 0.71428571]
#  [0.47945205 0.18720338 0.53333333 ... 1.         0.95121951 0.71428571]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn import metrics
print('The accuracy of Random Forest Classification is: ', metrics.accuracy_score(y_pred, y_test))
# Out:
# The accuracy of Random Forest Classification is:  1.0

# %% [markdown]
# Random forest is the best model 100% accuracy
